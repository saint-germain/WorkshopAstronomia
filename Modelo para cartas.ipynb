# %% [markdown]
# ## Código para crear cartas para el II Workshop de Astronomía en los Andes

# %%
from tempfile import mkstemp
from shutil import move
from os import close,remove
    
def replaceagn(file_path, pattern, subst):
    #Create temp file
    fh, abs_path = mkstemp()
    with open(abs_path,'w') as new_file:
        with open(file_path) as old_file:
            for line in old_file:
                new_file.write(line.replace(pattern, subst))
    close(fh)
    #Remove original file
    remove(file_path)
    #Move new file
    move(abs_path, file_path)

# %%
import pandas as pd
df = pd.read_csv('charlas.csv', index_col=0)
b='formal_letter_2.tex'
tot=len(df)

# %%
for k in range(0,tot):
    c=df.Apellido.iloc[k][0]+'_'+df.Correo.iloc[k][0:5]+'_'+str(df.index[k])
    cname='carta_%s.tex' %c
    # !cp $b $cname
    replaceagn(cname,'TITULO',df.Titulo.iloc[k])
    replaceagn(cname,'PREFIJO',df.Prefijo.iloc[k])
    replaceagn(cname,'NOMBRE',df.Nombre.iloc[k])
    replaceagn(cname,'APELLIDO',df.Apellido.iloc[k])
    replaceagn(cname,'INSTITUCION',df.Instituto.iloc[k])
    replaceagn(cname,'PREGEN',df.Pregen.iloc[k])
    replaceagn(cname,'CHOP',df.CHOP.iloc[k])
    # !pdflatex $cname
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_andre_1.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# (./carta_A_andre_1.aux)
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_andre_1.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_A_andre_1.pdf (1 page, 30737 bytes).
# Transcript written on carta_A_andre_1.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_jdlaa_2.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_jdlaa_2.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_jdlaa_2.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_A_jdlaa_2.pdf (1 page, 30074 bytes).
# Transcript written on carta_A_jdlaa_2.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_B_pilih_3.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_B_pilih_3.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_B_pilih_3.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_B_pilih_3.pdf (1 page, 30519 bytes).
# Transcript written on carta_B_pilih_3.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_B_l.ben_4.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_B_l.ben_4.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_B_l.ben_4.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_B_l.ben_4.pdf (1 page, 30274 bytes).
# Transcript written on carta_B_l.ben_4.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_B_l.ben_5.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_B_l.ben_5.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_B_l.ben_5.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_B_l.ben_5.pdf (1 page, 29976 bytes).
# Transcript written on carta_B_l.ben_5.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_B_oaboh_6.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_B_oaboh_6.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_B_oaboh_6.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_B_oaboh_6.pdf (1 page, 30037 bytes).
# Transcript written on carta_B_oaboh_6.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_C_gicar_7.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_C_gicar_7.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_C_gicar_7.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_C_gicar_7.pdf (1 page, 30222 bytes).
# Transcript written on carta_C_gicar_7.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_C_farid_8.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_C_farid_8.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_C_farid_8.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_C_farid_8.pdf (1 page, 30340 bytes).
# Transcript written on carta_C_farid_8.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_G_crisg_9.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_G_crisg_9.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_G_crisg_9.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_G_crisg_9.pdf (1 page, 29947 bytes).
# Transcript written on carta_G_crisg_9.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_M_ymmol_10.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_M_ymmol_10.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_M_ymmol_10.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_M_ymmol_10.pdf (1 page, 30581 bytes).
# Transcript written on carta_M_ymmol_10.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_P_angel_11.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_P_angel_11.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_P_angel_11.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_P_angel_11.pdf (1 page, 30614 bytes).
# Transcript written on carta_P_angel_11.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_P_Fanny_12.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_P_Fanny_12.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_P_Fanny_12.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_P_Fanny_12.pdf (1 page, 30384 bytes).
# Transcript written on carta_P_Fanny_12.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_R_hecto_13.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_R_hecto_13.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_R_hecto_13.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_R_hecto_13.pdf (1 page, 30022 bytes).
# Transcript written on carta_R_hecto_13.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_S_dicas_14.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_S_dicas_14.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_S_dicas_14.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_S_dicas_14.pdf (1 page, 31019 bytes).
# Transcript written on carta_S_dicas_14.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_T_tovar_15.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_T_tovar_15.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_T_tovar_15.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_T_tovar_15.pdf (1 page, 30482 bytes).
# Transcript written on carta_T_tovar_15.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_V_kviei_16.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_V_kviei_16.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
#
# Underfull \hbox (badness 10000) in paragraph at lines 63--64
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
#
# Underfull \hbox (badness 10000) in paragraph at lines 65--67
#
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_V_kviei_16.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb>
# Output written on carta_V_kviei_16.pdf (1 page, 30191 bytes).
# Transcript written on carta_V_kviei_16.log.
