# %% [markdown]
# ## Código para crear cartas para el II Workshop de Astronomía en los Andes

# %%
from tempfile import mkstemp
from shutil import move
from os import close,remove
    
def replaceagn(file_path, pattern, subst):
    #Create temp file
    fh, abs_path = mkstemp()
    with open(abs_path,'w') as new_file:
        with open(file_path) as old_file:
            for line in old_file:
                new_file.write(line.replace(pattern, subst))
    close(fh)
    #Remove original file
    remove(file_path)
    #Move new file
    move(abs_path, file_path)

# %%
import pandas as pd
df = pd.read_csv('charlas.csv', index_col=0)
b='formal_letter_2.tex'
tot=len(df)

# %%
for k in range(0,tot):
    if df.WL.iloc[k]==0:
        c=df.Apellido.iloc[k][0]+'_'+df.Correo.iloc[k].strip()+'_'+str(int(df.index[k]))
        cname='carta_%s.tex' %c
        # !cp $b $cname
        replaceagn(cname,'TITULO',df.Titulo.iloc[k])
        replaceagn(cname,'PREFIJO',df.Prefijo.iloc[k])
        replaceagn(cname,'NOMBRE',df.Nombre.iloc[k])
        replaceagn(cname,'APELLIDO',df.Apellido.iloc[k])
        replaceagn(cname,'INSTITUCION',df.Instituto.iloc[k])
        replaceagn(cname,'PREGEN',df.Pregen.iloc[k])
        replaceagn(cname,'CHOP',df.CHOP.iloc[k])
        # !pdflatex $cname
# Out:
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_andrey.acosta@gmail.com_1.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_andrey.acosta@gmail.com_1.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_andrey.acosta@gmail.com_1.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_A_andrey.acosta@gmail.com_1.pdf (1 page, 36593 bytes).
# Transcript written on carta_A_andrey.acosta@gmail.com_1.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_eagredab@unal.edu.co_2.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_eagredab@unal.edu.co_2.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_eagredab@unal.edu.co_2.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_A_eagredab@unal.edu.co_2.pdf (1 page, 36214 bytes).
# Transcript written on carta_A_eagredab@unal.edu.co_2.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_estefaguilar@gmail.com_3.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_estefaguilar@gmail.com_3.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_estefaguilar@gmail.com_3.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_A_estefaguilar@gmail.com_3.pdf (1 page, 36761 bytes).
# Transcript written on carta_A_estefaguilar@gmail.com_3.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_juancearias@gmail.com_6.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_juancearias@gmail.com_6.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_juancearias@gmail.com_6.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_A_juancearias@gmail.com_6.pdf (1 page, 36163 bytes).
# Transcript written on carta_A_juancearias@gmail.com_6.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_jdlaag@gmail.com_7.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_jdlaag@gmail.com_7.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_jdlaag@gmail.com_7.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_A_jdlaag@gmail.com_7.pdf (1 page, 36013 bytes).
# Transcript written on carta_A_jdlaag@gmail.com_7.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_A_rjavendanor@unal.edu.co_8.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_A_rjavendanor@unal.edu.co_8.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_A_rjavendanor@unal.edu.co_8.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_A_rjavendanor@unal.edu.co_8.pdf (1 page, 36931 bytes).
# Transcript written on carta_A_rjavendanor@unal.edu.co_8.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_B_nobar.baella@gmail.com_9.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_B_nobar.baella@gmail.com_9.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_B_nobar.baella@gmail.com_9.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_B_nobar.baella@gmail.com_9.pdf (1 page, 36003 bytes).
# Transcript written on carta_B_nobar.baella@gmail.com_9.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_B_jbarbosau@ecci.edu.co_10.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_B_jbarbosau@ecci.edu.co_10.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_B_jbarbosau@ecci.edu.co_10.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_B
aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_D_fdubeibe@gmail.com_28.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_D_fdubeibe@gmail.com_28.pdf (1 page, 36508 bytes).
# Transcript written on carta_D_fdubeibe@gmail.com_28.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_E_djlexes@gmail.com_29.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ...
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_S_adsuarezc@unal.edu.co_88.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_S_adsuarezc@unal.edu.co_88.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_S_adsuarezc@unal.edu.co_88.pdf (1 page, 35974 bytes).
# Transcript written on carta_S_adsuarezc@unal.edu.co_88.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_T_joatorresce@unal.edu.co_90.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_T_joatorresce@unal.edu.co_90.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_T_joatorresce@unal.edu.co_90.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_T_joatorresce@unal.edu.co_90.pdf (1 page, 36609 bytes).
# Transcript written on carta_T_joatorresce@unal.edu.co_90.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_T_satorress@unal.edu.co_91.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_T_satorress@unal.edu.co_91.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_T_satorress@unal.edu.co_91.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_T_satorress@unal.edu.co_91.pdf (1 page, 35981 bytes).
# Transcript written on carta_T_satorress@unal.edu.co_91.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_T_tovar035@d.umn.edu_92.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_T_tovar035@d.umn.edu_92.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_T_tovar035@d.umn.edu_92.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_T_tovar035@d.umn.edu_92.pdf (1 page, 37312 bytes).
# Transcript written on carta_T_tovar035@d.umn.edu_92.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_T_tovar035@d.umn.edu_93.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_T_tovar035@d.umn.edu_93.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_T_tovar035@d.umn.edu_93.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_T_tovar035@d.umn.edu_93.pdf (1 page, 36424 bytes).
# Transcript written on carta_T_tovar035@d.umn.edu_93.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_V_martha92valencia@gmail.com_95.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_V_martha92valencia@gmail.com_95.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_V_martha92valencia@gmail.com_95.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_V_martha92valencia@gmail.com_95.pdf (1 page, 36251 byte
# s).
# Transcript written on carta_V_martha92valencia@gmail.com_95.log.
# This is pdfTeX, Version 3.14159265-2.6-1.40.15 (TeX Live 2014) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./carta_V_adrianacvr67@gmail.com_97.tex
# LaTeX2e <2014/05/01>
# Babel <3.9k> and hyphenation patterns for 78 languages loaded.
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlttr2.cls
# Document Class: scrlttr2 2013/12/19 v3.12 KOMA-Script document class (letter)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrkbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrbase.sty
# (/usr/local/texlive/2014/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrlfile.sty
# Package scrlfile, 2013/12/19 v3.12 KOMA-Script package (loading files)
#                   Copyright (C) Markus Kohm
#
# ))) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/scrsize12pt.clo)
# (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/typearea.sty
# Package typearea, 2013/12/19 v3.12 KOMA-Script package (type area)
#                   Copyright (C) Frank Neukam, 1992-1994
#                   Copyright (C) Markus Kohm, 1994-
#
# )) (/usr/local/texlive/2014/texmf-dist/tex/latex/koma-script/DIN.lco)
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.sty
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel-english/english.ldf
# (/usr/local/texlive/2014/texmf-dist/tex/generic/babel/babel.def)))
# No file carta_V_adrianacvr67@gmail.com_97.aux.
# Foldmarks: no
# Head of first page
# Foot of first page
# Address (backaddress, addressee)
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
#
# Overfull \hbox (48.33061pt too wide) in paragraph at lines 59--59
# $[]$
# Location field: empty
# Title: no
# Subject: no
# [1{/usr/local/texlive/2014/texmf-var/fonts/map/pdftex/updmap/pdftex.map}]
# (./carta_V_adrianacvr67@gmail.com_97.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2014/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2014/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmss8.pfb></usr/local/texlive/2014/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on carta_V_adrianacvr67@gmail.com_97.pdf (1 page, 36288 bytes).
# Transcript written on carta_V_adrianacvr67@gmail.com_97.log.
